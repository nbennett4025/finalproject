# %% [markdown]
# # Ballot Measures Funding Local Government
# This data set shows the success rate of local government funding measures across the state of Wahsington from 2011-2017. The goal of this research is to find patterns in what voters are willing to approove to expand local government in light of property tax caps in state law.

# %% [markdown]
# ## Descriptive Statistics
# Before any analysis is possible, we have to understand the general patterns in the data.

# %%
import pandas as pd

# %%
data= 'https://github.com/nbennett4025/Data/raw/master/ballotinitiativesWA.xlsx'

# %%
ballot=pd.read_excel(data,0)
ballot.dtypes
# Out:
# Jurisdiction                         object
# County                               object
# Government Type                      object
# Subject                              object
# Ballot Measure Text                  object
# Election Results                     object
# Yes %                               float64
# No %                                float64
# Election Month                       object
# Election Year                         int64
# Duration in Years Levy/Fee           object
# Amount of Levy (Per $1000 A/V)      float64
# Tax Amount                          float64
# Bond Amount                         float64
# Funding Type/Statutory Authority     object
# dtype: object

# %%
ballotyes=ballot['Yes %']

# %% [markdown]
# To understand the data it is important to know that it takes a majority vote to raise taxes in a district. As the table below shows, less than 25% of measures fail.

# %%
ballotyes.describe()
# Out:
# count    1434.000000
# mean       62.784426
# std        14.206475
# min         0.000000
# 25%        54.750000
# 50%        64.575000
# 75%        72.442500
# max       100.000000
# Name: Yes %, dtype: float64

# %%
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(ballotyes.dropna(),kde=False,fit=norm)
plt.legend(('data fit to normal','data as it is'))
plt.title('How often do funding measures get 50% in WA?')
plt.show()

# %%
plot,dataBP=ballotyes.plot.box(vert=False,return_type='both')
plt.title('Distribution of Ballot Measure Approval Rates 2011-2017')
plt.show()
#looks like the data have a longer left tail, but are generally close to being 
#'normal'. On average it seems like things get the required 60% about
# a little more than half of the time

# %%
#Moving on to bi-variate analysis
from scipy import stats

# %% [markdown]
# ## Breakdown by government type, timing, and Subject
# There are a lot of different governments captured within the data. To facilitate analysis we can simplify the large number of categories into three big ones: cities, counties, and various special purpose governments. Counties, which proivde both regional and local services, have the most difficult time getting funding approved.

# %%
ballot['Government Type'].value_counts()
# Out:
# City                                      481
# Fire Protection District                  425
# Park District                             161
# County                                    110
# Cemetery District                          60
# Public Hospital District                   58
# Transportation Benefit District            40
# Port District                              20
# Emergency Medical Services District        16
# Water-Sewer District                       14
# Library District                           13
# Public Transportation Benefit Area         13
# Public Facilities District                  7
# Solid Waste Disposal District               6
# Mosquito Control District                   4
# Public Utility District                     2
# County Public Transportation Authority      2
# Regional Transit Authority                  1
# Flood Control Zone District                 1
# Name: Government Type, dtype: int64

# %%
values = list(ballot['Government Type'].value_counts().index)
values
# Out:
# ['City',
#  'Fire Protection District',
#  'Park District',
#  'County',
#  'Cemetery District',
#  'Public Hospital District',
#  'Transportation Benefit District',
#  'Port District',
#  'Emergency Medical Services District',
#  'Water-Sewer District',
#  'Library District',
#  'Public Transportation Benefit Area',
#  'Public Facilities District',
#  'Solid Waste Disposal District',
#  'Mosquito Control District',
#  'Public Utility District',
#  'County Public Transportation Authority',
#  'Regional Transit Authority',
#  'Flood Control Zone District']

# %%
city = values[0]
county = values[3]
govsimple = []

for value in ballot['Government Type']:
    if value in city:
        govsimple.append('City')
    else:
        if value in county:
            govsimple.append('County')
        else:
            govsimple.append('Special District')

# %%
ballot['govsimple'] = govsimple

# %%
sns.factorplot(x='govsimple', y= 'Yes %', data=ballot)
plt.title('Approval Rate by Government Type')
plt.show()

# %% [markdown]
# For election timing it seems that any non-November election is more likely to yield positive results. The year seems not to yield any predictable pattern.

# %%
# it would seem that counties have a harder time passing funding than cities
# or special districts
#Does the month of the election matter?
sns.factorplot(x='Election Month', y= 'Yes %', data=ballot, size=5)
plt.title('Approval Rate by Election Month')
plt.show()

# %%
sns.factorplot(x='Election Year', y= 'Yes %', data=ballot)
plt.title('By Election Year')
plt.show()
#looks like 2011 was a bad year for funding

# %%
#looking a little closer
ballot['Election Year'].value_counts()
# Out:
# 2016    252
# 2015    247
# 2017    213
# 2013    211
# 2012    205
# 2014    195
# 2011    111
# Name: Election Year, dtype: int64

# %% [markdown]
# Like government type, subject matter of the ballot measure needs to be simplified.

# %%
import numpy as np
subjects = list(ballot['Subject'].value_counts().index)
subjects
# Out:
# ['EMS',
#  'Parks and Recreation',
#  'Fire',
#  'Transportation',
#  'Other',
#  'Government Organization',
#  'Fire, EMS',
#  'Cemetery',
#  'Criminal Justice',
#  'Hospital',
#  'Library',
#  'Annexation, Fire',
#  'Water and Sewer',
#  'Annexation',
#  'Criminal Justice, Fire',
#  'Annexation, Library',
#  'Transportation, Water and Sewer, Other',
#  'Government Organization, Fire',
#  'Affordable Housing',
#  'Annexation, Transportation',
#  'Criminal Justice, Other',
#  'Transportation, Criminal Justice',
#  'Fire, EMS, Criminal Justice',
#  'Human Services',
#  'Fire, Other',
#  'Parks and Recreation, Other',
#  'Criminal Justice, Fire, Parks and Recreation, Other',
#  'Transportation, Parks and Recreation',
#  'Criminal Justice, Parks and Recreation, Other',
#  'Criminal Justice, Parks and Recreation',
#  'Annexation, Water-Sewer',
#  'Fire, Parks and Recreation, Other',
#  'Criminal Justice, Fire, Parks and Recreation, Transportation, Other',
#  'Criminal Justice, Library, Parks and Recreation, Other',
#  'Criminal Justice, Library, Parks and Recreation',
#  'Government Organization, Parks and Recreation',
#  'Government Organization, Criminal Justice',
#  'Fire, EMS, Transportation, Parks and Recreation, Criminal Justice',
#  'Criminal Justice, Human Services',
#  'Government Organization, Other',
#  'Transportation, Other',
#  'Fire, EMS, Transportation, Criminal Justice, Other']

# %%
parks = subjects[1]
transit = subjects[3]
govorg =subjects[5]
cemetery=subjects[7]
other=subjects[4]
water=subjects[12]
publicsafety = ['EMS', 'Fire', 'Fire, EMS', 'Criminal Justice']
human = ['Hospital', 'Library', 'Affordable Housing', 'Human Services']
annexation = ['Annexation, Fire', 'Annexation', 'Annexation, Library', 'Annexation, Transportation', 'Annexation, Water-Sewer']

# %%
parks
# Out:
# 'Parks and Recreation'

# %%
subsimple = []
for value in ballot['Subject']:
    if value in parks:
        subsimple.append('Parks')
    else:
        if value in transit:
            subsimple.append('Transit')
        else:
            if value in govorg:
                subsimple.append('Government Organization')
            else: 
                if value in cemetery:
                    subsimple.append('Cemetery')
                else:
                    if value in water:
                        subsimple.append('Water/Sewer')
                    else:
                        if value in other:
                            subsimple.append('Other')
                        else:
                            if value in publicsafety:
                                subsimple.append('Public Safety')
                            else:
                                if value in human:
                                    subsimple.append('Human Services')
                                else:
                                    if value in annexation:
                                        subsimple.append('Annexation')
                                    else:
                                        subsimple.append('Multiple')

# %%
ballot['subsimple'] = subsimple
ballot
# Out:
#                                            Jurisdiction          County  \
# 0              Aberdeen Transportation Benefit District    Grays Harbor
# 1     Adams County Cemetery District No. 1 - Washtuc...           Adams
# 2     Adams County Cemetery District No. 1 - Washtuc...           Adams
# 3     Adams County Cemetery District No. 1 - Washtuc...           Adams
# 4     Adams County Cemetery District No. 1 - Washtuc...           Adams
# 5     Adams County Cemetery District No. 1 - Washtuc...           Adams
# 6     Adams County Cemetery District No. 1 - Washtuc...           Adams
# 7        Adams County Cemetery District No. 2 - Othello           Adams
# 8        Adams County Cemetery District No. 2 - Othello           Adams
# 9     Adams County Cemetery District No. 3 - Lind Ce...           Adams
# 10    Adams County Cemetery District No. 3 - Lind Ce...           Adams
# 11    Adams County Cemetery District No. 3 - Lind Ce...           Adams
# 12    Adams County Cemetery District No. 3 - Lind Ce...           Adams
# 13    Adams County Cemetery District No. 3 - Lind Ce...           Adams
# 14    Adams County Cemetery District No. 3 - Lind Ce...           Adams
# 15    Adams County Fire Protection District No. 4 - ...           Adams
# 16    Adams County Fire Protection District No. 4 - ...           Adams
# 17    Adams County Fire Protection District No. 4 - ...           Adams
# 18    Adams County Fire Protection District No. 4 - ...           Adams
# 19    Adams County Fire Protection District No. 4 - ...           Adams
# 20    Adams County Fire Protection District No. 4 - ...           Adams
# 21    Adams County Fire Protection District No. 7 - ...           Adams
# 22    Adams County Fire Protection District No. 7 - ...           Adams
# 23    Adams County Park and Recreation District 2 - ...           Adams
# 24    Adams County Park and Recreation District 2 - ...           Adams
# 25    Adams County Park and Recreation District 2 - ...           Adams
# 26    Adams County Park and Recreation District 3 - ...           Adams
# 27    Adams County Park and Recreation District 3 - ...           Adams
# 28    Adams County Park and Recreation District 3 - ...           Adams
# 29    Adams County Park and Recreation District 3 - ...           Adams
# ...                                                 ...             ...
# 1404                                           Wilkeson          Pierce
# 1405               William Shore Memorial Pool District         Clallam
# 1406                                            Winlock           Lewis
# 1407                                           Winthrop        Okanogan
# 1408                                           Winthrop        Okanogan
# 1409                        Woodinville Fire and Rescue            King
# 1410                                           Woodland  Clark, Cowlitz
# 1411                                           Woodland  Clark, Cowlitz
# 1412                                           Woodland  Clark, Cowlitz
# 1413     Woodland Swimming Pool and Recreation District  Clark, Cowlitz
# 1414           Woodland Transportation Benefit District  Clark, Cowlitz
# 1415           Woodland Transportation Benefit District  Clark, Cowlitz
# 1416                                            Woodway       Snohomish
# 1417                                             Yacolt           Clark
# 1418                                             Yacolt           Clark
# 1419                                             Yacolt           Clark
# 1420                                             Yakima          Yakima
# 1421                                             Yakima          Yakima
# 1422                                             Yakima          Yakima
# 1423                                      Yakima County          Yakima
# 1424                                      Yakima County          Yakima
# 1425                                      Yakima County          Yakima
# 1426                                      Yakima County          Yakima
# 1427                                      Yakima County          Yakima
# 1428  Yakima County Fire Protection District No. 1 -...          Yakima
# 1429  Yakima County Fire Protection District No. 1 -...          Yakima
# 1430      Yakima County Fire Protection District No. 14          Yakima
# 1431       Yakima County Fire Protection District No. 6          Yakima
# 1432                                               Yelm        Thurston
# 1433                                               Yelm        Thurston
#
#                       Government Type  \
# 0     Transportation Benefit District
# 1                   Cemetery District
# 2                   Cemetery District
# 3                   Cemetery District
# 4                   Cemetery District
# 5                   Cemetery District
# 6                   Cemetery District
# 7                   Cemetery District
# 8                   Cemetery District
# 9                   Cemetery District
# 10                  Cemetery District
# 11                  Cemetery District
# 12                  Cemetery District
# 13                  Cemetery District
# 14                  Cemetery District
# 15           Fire Protection District
# 16           Fire Protection District
# 17           Fire Protection District
# 18           Fire Protection District
# 19           Fire Protection District
# 20           Fire Protection District
# 21           Fire Protection District
# 22           Fire Protection District
# 23                      Park District
# 24                      Park District
# 25                      Park District
# 26                      Park District
# 27                      Park District
# 28                      Park District
# 29                      Park District
# ...                               ...
# 1404                             City
# 1405                    Park District
# 1406                             City
# 1407                             City
# 1408                             City
# 1409         Fire Protection District
# 1410                             City
# 1411                             City
# 1412                             City
# 1413                    Park District
# 1414  Transportation Benefit District
# 1415  Transportation Benefit District
# 1416                             City
# 1417                             City
# 1418                             City
# 1419                             City
# 1420                             City
# 1421                             City
# 1422                             City
# 1423                           County
# 1424                           County
# 1425                           County
# 1426                           County
# 1427                           County
# 1428         Fire Protection District
# 1429         Fire Protection District
# 1430         Fire Protection District
# 1431         Fire Protection District
# 1432                             City
# 1433                             City
#
#                                                 Subject  \
# 0                                        Transportation
# 1                                              Cemetery
# 2                                              Cemetery
# 3                                              Cemetery
# 4                                              Cemetery
# 5                                              Cemetery
# 6                                              Cemetery
# 7                                              Cemetery
# 8                                              Cemetery
# 9                                              Cemetery
# 10                                             Cemetery
# 11                                             Cemetery
# 12                                             Cemetery
# 13                                             Cemetery
# 14                                             Cemetery
# 15                                                 Fire
# 16                                                 Fire
# 17                                                 Fire
# 18                                                 Fire
# 19                                                 Fire
# 20                                                 Fire
# 21                                                 Fire
# 22                                                 Fire
# 23                                 Parks and Recreation
# 24                                 Parks and Recreation
# 25                                 Parks and Recreation
# 26                                 Parks and Recreation
# 27                                 Parks and Recreation
# 28                                 Parks and Recreation
# 29                                 Parks and Recreation
# ...                                                 ...
# 1404                                                EMS
# 1405                               Parks and Recreation
# 1406                                Annexation, Library
# 1407                                   Annexation, Fire
# 1408                                                EMS
# 1409                                               Fire
# 1410                                   Criminal Justice
# 1411                                               Fire
# 1412                             Criminal Justice, Fire
# 1413                               Parks and Recreation
# 1414                                     Transportation
# 1415                                     Transportation
# 1416  Fire, EMS, Transportation, Criminal Justice, O...
# 1417                                                EMS
# 1418                                                EMS
# 1419                                              Other
# 1420                               Parks and Recreation
# 1421                                              Other
# 1422                                     Transportation
# 1423                                              Other
# 1424                                   Criminal Justice
# 1425                                   Criminal Justice
# 1426                                                EMS
# 1427                            Government Organization
# 1428                                          Fire, EMS
# 1429                                          Fire, EMS
# 1430                                          Fire, EMS
# 1431                                          Fire, EMS
# 1432                               Parks and Recreation
# 1433                               Parks and Recreation
#
#                                     Ballot Measure Text Election Results  \
# 0     TBD sales tax (6 years, 0.13%) for transportat...           Passed
# 1     Excess levy ($0.21) for cemetery maintenance a...           Passed
# 2     Excess levy ($0.27) for cemetery maintenance a...           Passed
# 3     Excess levy ($0.27) for cemetery maintenance a...           Passed
# 4     Excess levy ($0.19) for cemetery maintenance a...           Passed
# 5     Excess levy ($0.26) for cemetery maintenance a...           Passed
# 6     Excess levy ($0.26) for cemetery maintenance a...           Passed
# 7     Excess levy ($0.02) for cemetery maintenance a...           Failed
# 8     Excess levy ($0.02) for cemetery maintenance a...           Failed
# 9     Excess levy ($0.11) for cemetery maintenance a...           Failed
# 10    Excess levy ($0.12) for cemetery maintenance a...           Passed
# 11    Excess levy ($0.12) for cemetery maintenance a...           Passed
# 12    Excess levy ($0.12) for cemetery maintenance a...           Passed
# 13    Excess levy ($0.15) for cemetery maintenance a...           Passed
# 14    Excess levy ($0.16) for cemetery maintenance a...           Passed
# 15    Fire district excess levy (1 year, $0.66) for ...           Passed
# 16    Excess levy ($1.35) for construction, maintena...           Passed
# 17    Fire district excess levy (1 year, $1.35) for ...           Passed
# 18    Fire district excess levy (1 year, $1.35) for ...           Passed
# 19    Excess fire district levy (1 year, $1.35) for ...           Passed
# 20    Excess fire district levy (1 year, $1.35) for ...           Passed
# 21    Fire district excess levy (2 years, $0.43) for...           Passed
# 22    Fire district excess levy (2 years, $0.47) for...           Passed
# 23    Excess levy ($0.73) for swimming pool maintena...           Passed
# 24    Excess levy ($1.08) for swimming pool maintena...           Passed
# 25    Excess levy ($1.11) for maintenance and operat...           Failed
# 26    Excess levy ($0.24) for swimming pool maintena...           Passed
# 27    Excess levy ($0.24) for swimming pool maintena...           Passed
# 28    Excess levy ($0.25) for swimming pool maintena...           Passed
# 29    Excess levy ($0.24) for swimming pool maintena...           Passed
# ...                                                 ...              ...
# 1404     EMS levy (6 years, initial imposition, $0.25).           Passed
# 1405  Bonds (30 years, $3.5 million) to renovate and...           Passed
# 1406       Annexation into Timberland Regional Library.           Passed
# 1407  Annexation into Okanogan County Fire District ...           Passed
# 1408                EMS levy renewal (10 years, $0.50).           Passed
# 1409  Fire benefit charges, continued imposition (6 ...           Passed
# 1410  Single-year levy lid lift (increase of $0.78 t...           Failed
# 1411  Forming the Clark County Regional Fire Authori...           Failed
# 1412  Public safety sales tax (0.1%) for new police ...           Passed
# 1413  Bonds (20 years, $7.99 million) for design and...           Failed
# 1414  TBD sales tax (10 years, 0.2%) for Transportat...           Failed
# 1415  TBD sales tax (10 years, 0.2%) for transportat...           Failed
# 1416  Single-year levy lid lift (to $2.48, permanent...           Passed
# 1417  Excess levy ($1.40) for maintenance, operation...           Passed
# 1418  Excess levy ($1.50) for EMS maintenance and op...           Passed
# 1419  Excess levy ($1.00) for town maintenance and o...           Failed
# 1420  City charter amendment creating a dedicated pa...           Passed
# 1421  City charter amendment requiring at least 5 co...           Passed
# 1422  City charter amendment creating a dedicated st...           Passed
# 1423  Advisory vote on whether the county should con...         Advisory
# 1424  Public safety sales tax (0.3%) for public safe...           Passed
# 1425  Juvenile detention and jail sales tax (10 year...           Failed
# 1426                EMS levy renewal (10 years, $0.25).           Passed
# 1427  Establishing a board of freeholders to frame a...           Failed
# 1428  Multi-year levy lid lift (to $1.00, 6 years/pe...           Passed
# 1429  Bonds (20 years, $2.2 million) to replace and ...           Passed
# 1430  Multi-year levy lid lift (to $1.00, 6 years/pe...           Passed
# 1431  Single-year levy lid lift (to $1.00, permanent...           Passed
# 1432  Bonds (25 years, $5.7 million) for a new commu...           Failed
# 1433  Bonds (25 years, $5.7 million) for a new commu...           Failed
#
#        Yes %   No % Election Month  Election Year  \
# 0      62.83  37.17       February           2013
# 1      76.84  23.16         August           2017
# 2      70.97  29.03         August           2016
# 3      85.22  14.78         August           2015
# 4      81.82  18.18         August           2014
# 5      85.94  14.06         August           2013
# 6      84.70  16.30         August           2012
# 7      63.52  36.48       NOVEMBER           2017
# 8      50.86  49.14       November           2016
# 9      57.62  42.38       November           2017
# 10     61.12  38.88       November           2016
# 11     61.51  38.49       November           2015
# 12     67.06  32.94       November           2014
# 13     65.91  34.09       November           2013
# 14     64.97  35.33       November           2012
# 15    100.00   0.00       November           2017
# 16     72.73  27.27       November           2016
# 17    100.00   0.00       November           2015
# 18    100.00   0.00       November           2014
# 19    100.00   0.00       November           2013
# 20    100.00   0.00       November           2012
# 21     96.08   3.92         August           2015
# 22     89.29  10.71         August           2013
# 23     61.48  38.52         August           2016
# 24     68.50  31.50         August           2013
# 25     56.76  43.24       November           2012
# 26     69.35  30.65         August           2017
# 27     64.59  35.41         August           2016
# 28     73.57  26.43         August           2015
# 29     66.09  33.91         August           2014
# ...      ...    ...            ...            ...
# 1404   62.79  37.21       November           2011
# 1405   70.07  29.94       November           2017
# 1406   70.26  29.74       November           2014
# 1407   76.52  23.48       February           2017
# 1408   84.21  15.79       February           2013
# 1409   88.10  11.90          April           2013
# 1410   49.30  50.70       November           2017
# 1411   54.78  45.22          April           2015
# 1412   54.15  45.85       November           2011
# 1413   49.00  51.00       November           2017
# 1414   47.45  52.55       November           2017
# 1415   48.44  51.56       November           2016
# 1416   39.68  60.32       November           2016
# 1417   89.74  10.26         August           2017
# 1418   80.93  19.07         August           2014
# 1419   35.14  64.86       November           2012
# 1420   68.69  31.31       November           2014
# 1421   67.40  32.60       November           2013
# 1422   72.39  27.61         August           2013
# 1423   58.94  41.06       November           2017
# 1424   74.16  25.84       November           2015
# 1425   47.21  52.79         August           2012
# 1426   78.38  21.62       November           2011
# 1427   33.33  66.67       November           2011
# 1428   64.17  35.83         August           2014
# 1429   66.81  33.19       November           2012
# 1430   75.17  24.83         August           2016
# 1431   71.09  28.91       November           2017
# 1432   52.14  47.86       November           2013
# 1433   54.48  45.52         August           2013
#
#           Duration in Years Levy/Fee  Amount of Levy (Per $1000 A/V)  \
# 0                                  6                             NaN
# 1                                  1                            0.21
# 2                                  1                            0.27
# 3                                  1                            0.27
# 4                                  1                            0.19
# 5                                  1                            0.26
# 6                                  1                            0.26
# 7                                  1                            0.02
# 8                                  1                            0.02
# 9                                  1                            0.11
# 10                                 1                            0.12
# 11                                 1                            0.12
# 12                                 1                            0.12
# 13                                 1                            0.15
# 14                                 1                            0.16
# 15                                 1                            0.66
# 16                                 1                            1.35
# 17                                 1                            1.35
# 18                                 1                            1.35
# 19                                 1                            1.35
# 20                                 1                            1.35
# 21                                 2                            0.43
# 22                                 2                            0.47
# 23                                 1                            0.73
# 24                                 1                            1.08
# 25                                 1                            1.11
# 26                                 1                            0.24
# 27                                 1                            0.24
# 28                                 1                            0.25
# 29                                 1                            0.24
# ...                              ...                             ...
# 1404                               6                            0.25
# 1405                              30                             NaN
# 1406                             NaN                             NaN
# 1407                             NaN                             NaN
# 1408                              10                            0.50
# 1409                               6                             NaN
# 1410                    1, permanent                            2.84
# 1411                             NaN                             NaN
# 1412                             NaN                             NaN
# 1413                              20                             NaN
# 1414                              10                             NaN
# 1415                              10                             NaN
# 1416         Single-year (permanent)                            2.48
# 1417                               1                            1.40
# 1418                               1                            1.50
# 1419                               1                            1.00
# 1420                             NaN                             NaN
# 1421                             NaN                             NaN
# 1422                             NaN                             NaN
# 1423                             NaN                             NaN
# 1424                             NaN                             NaN
# 1425                              10                             NaN
# 1426                              10                            0.25
# 1427                             NaN                             NaN
# 1428  Multi-year (6 years/permanent)                            1.00
# 1429                              20                             NaN
# 1430  Multi-year (6 years/permanent)                            1.00
# 1431                    1, permanent                            1.00
# 1432                             NaN                             NaN
# 1433                              25                             NaN
#
#       Tax Amount  Bond Amount  \
# 0         0.0013          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# 5            NaN          NaN
# 6            NaN          NaN
# 7            NaN          NaN
# 8            NaN          NaN
# 9            NaN          NaN
# 10           NaN          NaN
# 11           NaN          NaN
# 12           NaN          NaN
# 13           NaN          NaN
# 14           NaN          NaN
# 15           NaN          NaN
# 16           NaN          NaN
# 17           NaN          NaN
# 18           NaN          NaN
# 19           NaN          NaN
# 20           NaN          NaN
# 21           NaN          NaN
# 22           NaN          NaN
# 23           NaN          NaN
# 24           NaN          NaN
# 25           NaN          NaN
# 26           NaN          NaN
# 27           NaN          NaN
# 28           NaN          NaN
# 29           NaN          NaN
# ...          ...          ...
# 1404         NaN          NaN
# 1405         NaN    3500000.0
# 1406         NaN          NaN
# 1407         NaN          NaN
# 1408         NaN          NaN
# 1409         NaN          NaN
# 1410         NaN          NaN
# 1411         NaN          NaN
# 1412      0.0010          NaN
# 1413         NaN    7990000.0
# 1414      0.0020          NaN
# 1415      0.0020          NaN
# 1416         NaN          NaN
# 1417         NaN          NaN
# 1418         NaN          NaN
# 1419         NaN          NaN
# 1420         NaN          NaN
# 1421         NaN          NaN
# 1422         NaN          NaN
# 1423         NaN          NaN
# 1424      0.0030          NaN
# 1425      0.0010          NaN
# 1426         NaN          NaN
# 1427         NaN          NaN
# 1428         NaN          NaN
# 1429         NaN    2200000.0
# 1430         NaN          NaN
# 1431         NaN          NaN
# 1432         NaN    5742000.0
# 1433         NaN    5742000.0
#
#                        Funding Type/Statutory Authority         govsimple  \
# 0     Transportation Benefit District Sales Tax (RCW...  Special District
# 1            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 2            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 3            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 4            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 5            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 6            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 7            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 8            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 9            Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 10           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 11           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 12           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 13           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 14           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 15            Fire District Excess Levy (RCW 84.52.130)  Special District
# 16            Fire District Excess Levy (RCW 84.52.130)  Special District
# 17            Fire District Excess Levy (RCW 84.52.130)  Special District
# 18            Fire District Excess Levy (RCW 84.52.130)  Special District
# 19            Fire District Excess Levy (RCW 84.52.130)  Special District
# 20            Fire District Excess Levy (RCW 84.52.130)  Special District
# 21            Fire District Excess Levy (RCW 84.52.130)  Special District
# 22            Fire District Excess Levy (RCW 84.52.130)  Special District
# 23           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 24           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 25           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 26           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 27           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 28           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# 29           Excess Levy (RCW 84.52.052, RCW 84.52.054)  Special District
# ...                                                 ...               ...
# 1404                           EMS Levy (RCW 84.52.069)              City
# 1405                               Bond (RCW 84.52.056)  Special District
# 1406                                                NaN              City
# 1407                                                NaN              City
# 1408                           EMS Levy (RCW 84.52.069)              City
# 1409       Fire District Benefit Charge (RCW 52.18.010)  Special District
# 1410                      Levy Lid Lift (RCW 84.55.050)              City
# 1411                                                NaN              City
# 1412            Public Safety Sales Tax (RCW 82.14.450)              City
# 1413                               Bond (RCW 84.52.056)  Special District
# 1414  Transportation Benefit District Sales Tax (RCW...  Special District
# 1415  Transportation Benefit District Sales Tax (RCW...  Special District
# 1416                      Levy Lid Lift (RCW 84.55.050)              City
# 1417         Excess Levy (RCW 84.52.052, RCW 84.52.054)              City
# 1418         Excess Levy (RCW 84.52.052, RCW 84.52.054)              City
# 1419         Excess Levy (RCW 84.52.052, RCW 84.52.054)              City
# 1420                                                NaN              City
# 1421                                                NaN              City
# 1422                                                NaN              City
# 1423                                                NaN            County
# 1424            Public Safety Sales Tax (RCW 82.14.450)            County
# 1425  Juvenile Detention Facilities and Jails Sales ...            County
# 1426                           EMS Levy (RCW 84.52.069)            County
# 1427                                                NaN            County
# 1428                      Levy Lid Lift (RCW 84.55.050)  Special District
# 1429                               Bond (RCW 84.52.056)  Special District
# 1430                      Levy Lid Lift (RCW 84.55.050)  Special District
# 1431                      Levy Lid Lift (RCW 84.55.050)  Special District
# 1432                               Bond (RCW 84.52.056)              City
# 1433                               Bond (RCW 84.52.056)              City
#
#                     subsimple
# 0                     Transit
# 1                    Cemetery
# 2                    Cemetery
# 3                    Cemetery
# 4                    Cemetery
# 5                    Cemetery
# 6                    Cemetery
# 7                    Cemetery
# 8                    Cemetery
# 9                    Cemetery
# 10                   Cemetery
# 11                   Cemetery
# 12                   Cemetery
# 13                   Cemetery
# 14                   Cemetery
# 15              Public Safety
# 16              Public Safety
# 17              Public Safety
# 18              Public Safety
# 19              Public Safety
# 20              Public Safety
# 21              Public Safety
# 22              Public Safety
# 23                      Parks
# 24                      Parks
# 25                      Parks
# 26                      Parks
# 27                      Parks
# 28                      Parks
# 29                      Parks
# ...                       ...
# 1404            Public Safety
# 1405                    Parks
# 1406               Annexation
# 1407               Annexation
# 1408            Public Safety
# 1409            Public Safety
# 1410            Public Safety
# 1411            Public Safety
# 1412                 Multiple
# 1413                    Parks
# 1414                  Transit
# 1415                  Transit
# 1416                 Multiple
# 1417            Public Safety
# 1418            Public Safety
# 1419                    Other
# 1420                    Parks
# 1421                    Other
# 1422                  Transit
# 1423                    Other
# 1424            Public Safety
# 1425            Public Safety
# 1426            Public Safety
# 1427  Government Organization
# 1428            Public Safety
# 1429            Public Safety
# 1430            Public Safety
# 1431            Public Safety
# 1432                    Parks
# 1433                    Parks
#
# [1434 rows x 17 columns]

# %%
sns.factorplot(x='subsimple', y= 'Yes %', data=ballot,size=7, aspect=2)
plt.title('By subject matter')
plt.show()

# %% [markdown]
# ## Correlation and Regression Analysis

# %%
#time for some correlations
ballot.dtypes
# Out:
# Jurisdiction                         object
# County                               object
# Government Type                      object
# Subject                              object
# Ballot Measure Text                  object
# Election Results                     object
# Yes %                               float64
# No %                                float64
# Election Month                       object
# Election Year                         int64
# Duration in Years Levy/Fee           object
# Amount of Levy (Per $1000 A/V)      float64
# Tax Amount                          float64
# Bond Amount                         float64
# Funding Type/Statutory Authority     object
# govsimple                            object
# dtype: object

# %%
yes = ballot['Yes %']
no = ballot['No %']
duration = ballot['Duration in Years Levy/Fee']
levy = ballot['Amount of Levy (Per $1000 A/V)']
tax = ballot['Tax Amount']
bond = ballot['Bond Amount']

# %%
data={'yes':yes, 'no':no, 'duration':duration, 'levy':levy, 'tax':tax, 'bond':bond}

# %%
ballotcorr = pd.DataFrame.from_dict(data)

# %%
#looks like duration is going to be a problem so lets drop it as a variable
ballotcorr.drop('duration',axis=1,inplace=True)

# %%
ballotcorr.corr('pearson', 1)
# Out:
#           bond      levy        no       tax       yes
# bond  1.000000       NaN -0.075546       NaN  0.075543
# levy       NaN  1.000000  0.141061 -1.000000 -0.137931
# no   -0.075546  0.141061  1.000000 -0.254060 -0.979699
# tax        NaN -1.000000 -0.254060  1.000000  0.254068
# yes   0.075543 -0.137931 -0.979699  0.254068  1.000000

# %%
pd.plotting.scatter_matrix(ballotcorr,figsize=(12,12))
plt.show()

# %%
# alright it looks like only certain types of funding respond at all to the amount being asked for

# %%
#in order to have a good regression we need to turn some variables into dummy variables

# %%
ballot['Subject'].value_counts()
# Out:
# EMS                                                                    214
# Parks and Recreation                                                   200
# Fire                                                                   190
# Transportation                                                         134
# Other                                                                  117
# Government Organization                                                115
# Fire, EMS                                                              114
# Cemetery                                                                60
# Criminal Justice                                                        55
# Hospital                                                                44
# Library                                                                 32
# Annexation, Fire                                                        32
# Water and Sewer                                                         23
# Annexation                                                              18
# Criminal Justice, Fire                                                  15
# Annexation, Library                                                      9
# Transportation, Water and Sewer, Other                                   7
# Government Organization, Fire                                            6
# Affordable Housing                                                       5
# Annexation, Transportation                                               4
# Criminal Justice, Other                                                  4
# Transportation, Criminal Justice                                         4
# Fire, EMS, Criminal Justice                                              3
# Human Services                                                           3
# Fire, Other                                                              3
# Parks and Recreation, Other                                              3
# Criminal Justice, Fire, Parks and Recreation, Other                      3
# Transportation, Parks and Recreation                                     2
# Criminal Justice, Parks and Recreation, Other                            2
# Criminal Justice, Parks and Recreation                                   1
# Annexation, Water-Sewer                                                  1
# Fire, Parks and Recreation, Other                                        1
# Criminal Justice, Fire, Parks and Recreation, Transportation, Other      1
# Criminal Justice, Library, Parks and Recreation, Other                   1
# Criminal Justice, Library, Parks and Recreation                          1
# Government Organization, Parks and Recreation                            1
# Government Organization, Criminal Justice                                1
# Fire, EMS, Transportation, Parks and Recreation, Criminal Justice        1
# Criminal Justice, Human Services                                         1
# Government Organization, Other                                           1
# Transportation, Other                                                    1
# Fire, EMS, Transportation, Criminal Justice, Other                       1
# Name: Subject, dtype: int64

# %%
ballot['subsimple'].value_counts()
# Out:
# Public Safety              573
# Parks                      200
# Transit                    134
# Other                      117
# Government Organization    115
# Human Services              84
# Annexation                  64
# Multiple                    64
# Cemetery                    60
# Water/Sewer                 23
# Name: subsimple, dtype: int64

# %%
#dummy recodes
#1 - election month
months = list(ballot['Election Month'].value_counts().index)
months
# Out:
# ['November', 'August', 'February', 'April', 'NOVEMBER']

# %%
november = months[0]
august = months[1]
february = months[2]
april = months[3]
novembercap = months[4]

isnovember = []
for value in ballot['Election Month']:
    if value in november or novembercap:
        isnovember.append(1)
    else:
        isnovember.append(0)

ballot['isnovember'] = isnovember

isaugust =[]
for value in ballot['Election Month']:
    if value in august:
        isaugust.append(1)
    else:
        isaugust.append(0)

ballot['isaugust'] = isaugust

isfebruary =[]
for value in ballot['Election Month']:
    if value in february:
        isfebruary.append(1)
    else:
        isfebruary.append(0)

ballot['isfebruary'] = isfebruary

isapril =[]
for value in ballot['Election Month']:
    if value in april:
        isapril.append(1)
    else:
        isapril.append(0)

ballot['isapril'] = isapril

# %%
#recoding election results as a dummy variable
result = list(ballot['Election Results'].value_counts().index)
result
# Out:
# ['Passed', 'Failed', 'Advisory']

# %%
passing=result[0]
failing=result[1]
passed=[]
for value in ballot['Election Results']:
    if value in passing:
        passed.append(1)
    else:
        if value in failing:
            passed.append(0)
        else:
            passed.append(None)
            
ballot['passed']=passed

# %%
ballot['levy']=ballot['Amount of Levy (Per $1000 A/V)']
ballot['salestax'] = ballot['Tax Amount']
ballot['bondamt'] = ballot['Bond Amount']

# %%
ballot.dtypes
# Out:
# Jurisdiction                         object
# County                               object
# Government Type                      object
# Subject                              object
# Ballot Measure Text                  object
# Election Results                     object
# Yes %                               float64
# No %                                float64
# Election Month                       object
# Election Year                         int64
# Duration in Years Levy/Fee           object
# Amount of Levy (Per $1000 A/V)      float64
# Tax Amount                          float64
# Bond Amount                         float64
# Funding Type/Statutory Authority     object
# govsimple                            object
# subsimple                            object
# isnovember                            int64
# isaugust                              int64
# isfebruary                            int64
# isapril                               int64
# passed                              float64
# levy                                float64
# salestax                            float64
# bondamt                             float64
# dtype: object

# %%
#now that the relavent variables are ready lets see if the x's are correlated
xvars = ballot.columns[[19,20,21,22,23,24]]
ballot[xvars].corr()
# Out:
#             isfebruary   isapril    passed      levy  salestax   bondamt
# isfebruary    1.000000 -0.084309  0.069492  0.036321 -0.046923 -0.081322
# isapril      -0.084309  1.000000  0.034492 -0.071166  0.367510  0.117694
# passed        0.069492  0.034492  1.000000 -0.061768  0.079036  0.052004
# levy          0.036321 -0.071166 -0.061768  1.000000 -1.000000       NaN
# salestax     -0.046923  0.367510  0.079036 -1.000000  1.000000       NaN
# bondamt      -0.081322  0.117694  0.052004       NaN       NaN  1.000000

# %%
#looks like we are in the clear, lets run the regression on 'passed'
import statsmodels.formula.api as smf
formulalevy='passed ~ levy + isaugust + isfebruary + isapril'
levylogit = smf.ols(formulalevy,data=ballot).fit()
print(levylogit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 passed   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     8.985
# Date:                Tue, 06 Mar 2018   Prob (F-statistic):           4.10e-07
# Time:                        09:09:14   Log-Likelihood:                -407.80
# No. Observations:                 887   AIC:                             825.6
# Df Residuals:                     882   BIC:                             849.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7832      0.023     34.384      0.000       0.738       0.828
# levy          -0.0379      0.019     -1.989      0.047      -0.075      -0.001
# isaugust       0.1188      0.029      4.051      0.000       0.061       0.176
# isfebruary     0.1923      0.050      3.874      0.000       0.095       0.290
# isapril        0.1965      0.059      3.317      0.001       0.080       0.313
# ==============================================================================
# Omnibus:                      191.966   Durbin-Watson:                   1.529
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              332.134
# Skew:                          -1.483   Prob(JB):                     7.55e-73
# Kurtosis:                       3.431   Cond. No.                         6.63
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.formula.api as smf
formulasales='passed ~ salestax + isaugust + isfebruary + isapril'
saleslogit = smf.ols(formulasales,data=ballot).fit()
print(saleslogit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 passed   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1.805
# Date:                Tue, 06 Mar 2018   Prob (F-statistic):              0.132
# Time:                        09:55:54   Log-Likelihood:                -76.281
# No. Observations:                 124   AIC:                             162.6
# Df Residuals:                     119   BIC:                             176.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6567      0.052     12.514      0.000       0.553       0.761
# salestax       0.3356      0.708      0.474      0.637      -1.067       1.739
# isaugust      -0.0673      0.111     -0.608      0.544      -0.286       0.152
# isfebruary     0.3425      0.161      2.126      0.036       0.024       0.661
# isapril        0.1433      0.131      1.091      0.278      -0.117       0.403
# ==============================================================================
# Omnibus:                      105.612   Durbin-Watson:                   1.626
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.458
# Skew:                          -0.705   Prob(JB):                     5.95e-05
# Kurtosis:                       1.667   Cond. No.                         17.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.formula.api as smf
formulabond='passed ~ bondamt + isaugust + isfebruary + isapril'
bondlogit = smf.ols(formulabond,data=ballot).fit()
print(bondlogit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 passed   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.268
# Date:                Tue, 06 Mar 2018   Prob (F-statistic):              0.288
# Time:                        09:57:56   Log-Likelihood:                -68.473
# No. Observations:                 101   AIC:                             146.9
# Df Residuals:                      96   BIC:                             160.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6072      0.070      8.693      0.000       0.469       0.746
# bondamt     6.442e-10   1.36e-09      0.475      0.636   -2.05e-09    3.34e-09
# isaugust      -0.1916      0.131     -1.467      0.146      -0.451       0.068
# isfebruary     0.2063      0.162      1.273      0.206      -0.115       0.528
# isapril        0.0013      0.139      0.010      0.992      -0.275       0.278
# ==============================================================================
# Omnibus:                        2.691   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.260   Jarque-Bera (JB):               13.960
# Skew:                          -0.387   Prob(JB):                     0.000930
# Kurtosis:                       1.351   Cond. No.                     1.47e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Moving along to clustering
#first step is to find a unique unit
len(ballot['Ballot Measure Text'].unique())==len(ballot['Ballot Measure Text'])
# Out:
# False

# %%
import geopandas as gpd

# %%
compressedmap = 'https://github.com/nbennett4025/Data/raw/master/WAOFM.zip'

# %%
countymap = gpd.GeoDataFrame.from_file(compressedmap)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-79-66060fb1ae91> in <module>()
# ----> 1 countymap = gpd.GeoDataFrame.from_file(compressedmap)
#
# ~\Anaconda3\lib\site-packages\geopandas\geodataframe.py in from_file(cls, filename, **kwargs)
#     165
#     166         """
# --> 167         return geopandas.io.file.read_file(filename, **kwargs)
#     168
#     169     @classmethod
#
# ~\Anaconda3\lib\site-packages\geopandas\io\file.py in read_file(filename, **kwargs)
#      17     """
#      18     bbox = kwargs.pop('bbox', None)
# ---> 19     with fiona.open(filename, **kwargs) as f:
#      20         crs = f.crs
#      21         if bbox is not None:
#
# ~\Anaconda3\lib\site-packages\fiona\__init__.py in open(path, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt)
#     160                 raise IOError("no such archive file: %r" % archive)
#     161         elif path != '-' and not os.path.exists(path):
# --> 162             raise IOError("no such file or directory: %r" % path)
#     163         c = Collection(path, mode, driver=driver, encoding=encoding,
#     164                        layer=layer, vsi=vsi, archive=archive,
#
# OSError: no such file or directory: 'github.com/nbennett4025/Data/raw/master/WAOFM.zip'
